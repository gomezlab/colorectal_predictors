# %%
from matplotlib import pyplot as plt

# %%
import matplotlib
matplotlib.rcParams.update({'font.size': 16})

# %%
# %store -r mean_col_ann_tpr
# %store -r mean_col_ann_fpr

# %store -r mean_col_lr_tpr
# %store -r mean_col_lr_fpr

# %store -r mean_col_rf_tpr
# %store -r mean_col_rf_fpr
# %store -r mean_col_xgb_tpr
# %store -r mean_col_xgb_fpr

# %%
plt.figure(num=None, figsize=(10, 9), dpi=300, facecolor='w', edgecolor='k')
plt.plot(mean_col_lr_fpr, mean_col_lr_tpr, color='royalblue', lw=2, label='lr')
plt.plot(mean_col_rf_fpr, mean_col_rf_tpr, color='royalblue', lw=2, label='rf')
plt.plot(mean_col_xgb_fpr, mean_col_xgb_tpr, color='royalblue', lw=2, label='xgb')
plt.plot(mean_col_ann_fpr, mean_col_ann_tpr, color='royalblue', lw=2, label='ANN')
plt.legend(loc="lower right")
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.plot([0, 1], [0, 1], 'k--', lw=1)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.savefig('roc.png', bbox_inches='tight')

# %%
# %store -r mean_col_lr_prec
# %store -r mean_col_lr_rec

# %%
# %store -r mean_col_ann_prec
# %store -r mean_col_ann_rec

# %%
# %store -r mean_col_xgb_prec
# %store -r mean_col_xgb_rec

# %%
# %store -r mean_col_rf_prec
# %store -r mean_col_rf_rec

# %%
plt.figure(num=None, figsize=(5, 5), dpi=300, facecolor='w', edgecolor='k')
plt.plot(mean_col_lr_rec, mean_col_lr_prec, color='royalblue', lw=2, label='lr')
plt.plot(mean_col_rf_rec, mean_col_rf_prec, color='royalblue', lw=2, label='rf')
plt.plot(mean_col_xgb_rec, mean_col_xgb_prec, color='royalblue', lw=2, label='xgb')
plt.plot(mean_col_ann_rec, mean_col_ann_prec, color='royalblue', lw=2, label='ann')
plt.axhline(y=0.00589, color='black', lw=1, linestyle='--')
plt.legend(loc="upper right")
plt.axis([0, 1, 0, 0.6])                                    # Not shown in the book
plt.xlabel('Recall (Sensitivity)') # Not shown
plt.ylabel('Precision (PPV)')    # Not shown
plt.grid(True)                                            # Not shown
plt.figure(figsize=(8, 6))                                    # Not shown
plt.show()
plt.savefig('roc.png', bbox_inches='tight')
