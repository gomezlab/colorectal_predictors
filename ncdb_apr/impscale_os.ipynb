# %%
import pandas as pd
import numpy as np

from sklearn.preprocessing import LabelEncoder, OrdinalEncoder
from sklearn.preprocessing import StandardScaler

from sklearn.impute import SimpleImputer

# %%
#send data to rename.ipynb to rename all categories from numbers into words
data = pd.read_csv('data/data_os_clean.csv', index_col=0)
print(data.shape)
data.head()
# Out:
# (33790, 35)
#                                                            Facility Type  \
# PUF_CASE_ID
# D66f458f9-bdc0-4c95-94a3-a5f8c5bb74f9          Academic/Research Program
# Dfc68ea23-71aa-4b0d-87c0-587b4ce13d04          Academic/Research Program
# D54a1d0da-4328-4ca5-8481-87cd73b33dd4          Academic/Research Program
# D62170955-5fc5-434e-8e6a-6a9e139851c4          Academic/Research Program
# Dbfa7903c-bd06-4e1c-9d22-a3d39ed96aee  Integrated Network Cancer Program
#
#                                       Facility Location   Age     Sex   Race  \
# PUF_CASE_ID
# D66f458f9-bdc0-4c95-94a3-a5f8c5bb74f9           Midwest  52.0  Female  White
# Dfc68ea23-71aa-4b0d-87c0-587b4ce13d04              West  49.0  Female  White
# D54a1d0da-4328-4ca5-8481-87cd73b33dd4           Midwest  58.0    Male  White
# D62170955-5fc5-434e-8e6a-6a9e139851c4           Midwest  80.0  Female  White
# Dbfa7903c-bd06-4e1c-9d22-a3d39ed96aee           Midwest  42.0  Female  White
#
#                                       Hispanic Ethnicity  \
# PUF_CASE_ID
# D66f458f9-bdc0-4c95-94a3-a5f8c5bb74f9       Non-Hispanic
# Dfc68ea23-71aa-4b0d-87c0-587b4ce13d04       Non-Hispanic
# D54a1d0da-4328-4ca5-8481-87cd73b33dd4       Non-Hispanic
# D62170955-5fc5-434e-8e6a-6a9e139851c4       Non-Hispanic
# Dbfa7903c-bd06-4e1c-9d22-a3d39ed96aee       Non-Hispanic
#
#                                                         Insurance Status  \
# PUF_CASE_ID
# D66f458f9-bdc0-4c95-94a3-a5f8c5bb74f9                        Not Insured
# Dfc68ea23-71aa-4b0d-87c0-587b4ce13d04  Private Insurance or Managed Care
# D54a1d0da-4328-4ca5-8481-87cd73b33dd4                           Medicaid
# D62170955-5fc5-434e-8e6a-6a9e139851c4                    Medicare/Public
# Dbfa7903c-bd06-4e1c-9d22-a3d39ed96aee  Private Insurance or Managed Care
#
#                                       Urban/Rural  Distance from Hospital  \
# PUF_CASE_ID
# D66f458f9-bdc0-4c95-94a3-a5f8c5bb74f9       Urban                     3.6
# Dfc68ea23-71aa-4b0d-87c0-587b4ce13d04       Urban                    11.4
# D54a1d0da-4328-4ca5-8481-87cd73b33dd4       Urban                    14.0
# D62170955-5fc5-434e-8e6a-6a9e139851c4       Urban                     NaN
# Dbfa7903c-bd06-4e1c-9d22-a3d39ed96aee       Urban                    12.7
#
#                                       Charlson-Deyo Score  ...  Stage T Stage  \
# PUF_CASE_ID                                                ...
# D66f458f9-bdc0-4c95-94a3-a5f8c5bb74f9                   0  ...     2A     2.0
# Dfc68ea23-71aa-4b0d-87c0-587b4ce13d04                   0  ...     3A     2.0
# D54a1d0da-4328-4ca5-8481-87cd73b33dd4                   0  ...     2B     3.0
# D62170955-5fc5-434e-8e6a-6a9e139851c4                   0  ...      1     1.0
# Dbfa7903c-bd06-4e1c-9d22-a3d39ed96aee                   0  ...      1     1.0
#
#                                        N Stage M Stage Pathologic Stage  \
# PUF_CASE_ID
# D66f458f9-bdc0-4c95-94a3-a5f8c5bb74f9      0.0       0       No surgery
# Dfc68ea23-71aa-4b0d-87c0-587b4ce13d04      1.0       0       No surgery
# D54a1d0da-4328-4ca5-8481-87cd73b33dd4      0.0       0       No surgery
# D62170955-5fc5-434e-8e6a-6a9e139851c4      0.0       0       No surgery
# Dbfa7903c-bd06-4e1c-9d22-a3d39ed96aee      0.0       0       No surgery
#
#                                        Facility Volume Quartile  \
# PUF_CASE_ID
# D66f458f9-bdc0-4c95-94a3-a5f8c5bb74f9                       3.0
# Dfc68ea23-71aa-4b0d-87c0-587b4ce13d04                       1.0
# D54a1d0da-4328-4ca5-8481-87cd73b33dd4                       3.0
# D62170955-5fc5-434e-8e6a-6a9e139851c4                       3.0
# Dbfa7903c-bd06-4e1c-9d22-a3d39ed96aee                       4.0
#
#                                       3-yr Mortality      Keratinizing  \
# PUF_CASE_ID
# D66f458f9-bdc0-4c95-94a3-a5f8c5bb74f9            0.0  Not Keratinizing
# Dfc68ea23-71aa-4b0d-87c0-587b4ce13d04            0.0  Not Keratinizing
# D54a1d0da-4328-4ca5-8481-87cd73b33dd4            0.0  Not Keratinizing
# D62170955-5fc5-434e-8e6a-6a9e139851c4            0.0  Not Keratinizing
# Dbfa7903c-bd06-4e1c-9d22-a3d39ed96aee            0.0  Not Keratinizing
#
#                                            Basaloid      Cloacogenic
# PUF_CASE_ID
# D66f458f9-bdc0-4c95-94a3-a5f8c5bb74f9  Not Basaloid  Not Cloacogenic
# Dfc68ea23-71aa-4b0d-87c0-587b4ce13d04      Basaloid  Not Cloacogenic
# D54a1d0da-4328-4ca5-8481-87cd73b33dd4  Not Basaloid  Not Cloacogenic
# D62170955-5fc5-434e-8e6a-6a9e139851c4  Not Basaloid  Not Cloacogenic
# Dbfa7903c-bd06-4e1c-9d22-a3d39ed96aee  Not Basaloid  Not Cloacogenic
#
# [5 rows x 35 columns]

# %%
data['Stage'].value_counts()
# Out:
# 2A    11551
# 3A     5748
# 3C     5601
# 1      5557
# 2B     3685
# 3B     1648
# Name: Stage, dtype: int64

# %%
data.loc[data['Stage'] == '1', 'Stage'] = 0
data.loc[data['Stage'] == '2A', 'Stage'] = 1
data.loc[data['Stage'] == '2B', 'Stage'] = 2
data.loc[data['Stage'] == '3A', 'Stage'] = 3
data.loc[data['Stage'] == '3B', 'Stage'] = 4
data.loc[data['Stage'] == '3C', 'Stage'] = 5
data['Stage'].value_counts()
# Out:
# 1    11551
# 3     5748
# 5     5601
# 0     5557
# 2     3685
# 4     1648
# Name: Stage, dtype: int64

# %%
data['Charlson-Deyo Score'].value_counts()
# Out:
# 0            26922
# 1             4201
# 3 or more     1575
# 2             1092
# Name: Charlson-Deyo Score, dtype: int64

# %%
data.loc[data['Charlson-Deyo Score'] == '0', 'Charlson-Deyo Score'] = 0
data.loc[data['Charlson-Deyo Score'] == '1', 'Charlson-Deyo Score'] = 1
data.loc[data['Charlson-Deyo Score'] == '2', 'Charlson-Deyo Score'] = 2
data.loc[data['Charlson-Deyo Score'] == '3 or more', 'Charlson-Deyo Score'] = 3
data['Charlson-Deyo Score'].value_counts()
# Out:
# 0    26922
# 1     4201
# 3     1575
# 2     1092
# Name: Charlson-Deyo Score, dtype: int64

# %%
#sort columns by proportion of missing values
pd.DataFrame(data.isnull().sum()/data.shape[0]).sort_values(by=0, ascending=False).head(20)
# Out:
#                                         0
# Reason for No Surgery            0.970761
# Lymphovascular Invasion          0.825806
# Post-op Length of Stay           0.798875
# Total Dose                       0.627493
# Tumor Size                       0.269074
# Income, Quartile                 0.107073
# No High School Degree, Quartile  0.105564
# Distance from Hospital           0.096123
# Surgical Margins                 0.050222
# Chemotherapy                     0.047292
# Hispanic Ethnicity               0.043770
# Facility Location                0.029121
# Facility Type                    0.029121
# Urban/Rural                      0.026221
# N Stage                          0.024741
# Pathologic Stage                 0.018615
# Post-op Readmission              0.017550
# T Stage                          0.017194
# Insurance Status                 0.016425
# Treatment Started, Days from Dx  0.015360

# %%
data['Reason for No Surgery'].fillna('Not indicated', inplace=True)
data['Post-op Length of Stay'].fillna(0, inplace=True)

# %%
data['Surgical Margins'].fillna('No Surgery', inplace=True)

# %%
cols = data.columns.to_list()
num_cols = ['Age', 'Distance from Hospital', 'Tumor Size', 'Treatment Started, Days from Dx', 'Post-op Length of Stay', 'Total Dose']
cat_cols = [x for x in cols if x not in num_cols]

# %%
data['Post-op Length of Stay'].fillna(0, inplace=True)

# %%
cat_cols.remove('Reason for No Surgery')
cat_cols.remove('Surgical Margins')

# %%
#set datatype of categorical columns to object
cat_imputer = SimpleImputer(strategy='constant', fill_value='unknown')
for col in cat_cols:
    data[col] = data[col].astype(str)
for x in cat_cols:
    data[x] = cat_imputer.fit_transform(data[x].values.reshape(-1,1))
num_imputer = SimpleImputer(strategy='median')
for x in num_cols:
    data[x] = num_imputer.fit_transform(data[x].values.reshape(-1,1))
#sort columns by proportion of missing values
pd.DataFrame(data.isnull().sum()/data.shape[0]).sort_values(by=0, ascending=False).head(5)
# Out:
#                                    0
# Facility Type                    0.0
# T Stage                          0.0
# No High School Degree, Quartile  0.0
# Income, Quartile                 0.0
# Medicaid Expansion               0.0

# %%
data.head()
# Out:
#                                                            Facility Type  \
# PUF_CASE_ID
# D66f458f9-bdc0-4c95-94a3-a5f8c5bb74f9          Academic/Research Program
# Dfc68ea23-71aa-4b0d-87c0-587b4ce13d04          Academic/Research Program
# D54a1d0da-4328-4ca5-8481-87cd73b33dd4          Academic/Research Program
# D62170955-5fc5-434e-8e6a-6a9e139851c4          Academic/Research Program
# Dbfa7903c-bd06-4e1c-9d22-a3d39ed96aee  Integrated Network Cancer Program
#
#                                       Facility Location   Age     Sex   Race  \
# PUF_CASE_ID
# D66f458f9-bdc0-4c95-94a3-a5f8c5bb74f9           Midwest  52.0  Female  White
# Dfc68ea23-71aa-4b0d-87c0-587b4ce13d04              West  49.0  Female  White
# D54a1d0da-4328-4ca5-8481-87cd73b33dd4           Midwest  58.0    Male  White
# D62170955-5fc5-434e-8e6a-6a9e139851c4           Midwest  80.0  Female  White
# Dbfa7903c-bd06-4e1c-9d22-a3d39ed96aee           Midwest  42.0  Female  White
#
#                                       Hispanic Ethnicity  \
# PUF_CASE_ID
# D66f458f9-bdc0-4c95-94a3-a5f8c5bb74f9       Non-Hispanic
# Dfc68ea23-71aa-4b0d-87c0-587b4ce13d04       Non-Hispanic
# D54a1d0da-4328-4ca5-8481-87cd73b33dd4       Non-Hispanic
# D62170955-5fc5-434e-8e6a-6a9e139851c4       Non-Hispanic
# Dbfa7903c-bd06-4e1c-9d22-a3d39ed96aee       Non-Hispanic
#
#                                                         Insurance Status  \
# PUF_CASE_ID
# D66f458f9-bdc0-4c95-94a3-a5f8c5bb74f9                        Not Insured
# Dfc68ea23-71aa-4b0d-87c0-587b4ce13d04  Private Insurance or Managed Care
# D54a1d0da-4328-4ca5-8481-87cd73b33dd4                           Medicaid
# D62170955-5fc5-434e-8e6a-6a9e139851c4                    Medicare/Public
# Dbfa7903c-bd06-4e1c-9d22-a3d39ed96aee  Private Insurance or Managed Care
#
#                                       Urban/Rural  Distance from Hospital  \
# PUF_CASE_ID
# D66f458f9-bdc0-4c95-94a3-a5f8c5bb74f9       Urban                     3.6
# Dfc68ea23-71aa-4b0d-87c0-587b4ce13d04       Urban                    11.4
# D54a1d0da-4328-4ca5-8481-87cd73b33dd4       Urban                    14.0
# D62170955-5fc5-434e-8e6a-6a9e139851c4       Urban                     8.4
# Dbfa7903c-bd06-4e1c-9d22-a3d39ed96aee       Urban                    12.7
#
#                                       Charlson-Deyo Score  ... Stage T Stage  \
# PUF_CASE_ID                                                ...
# D66f458f9-bdc0-4c95-94a3-a5f8c5bb74f9                   0  ...     1     2.0
# Dfc68ea23-71aa-4b0d-87c0-587b4ce13d04                   0  ...     3     2.0
# D54a1d0da-4328-4ca5-8481-87cd73b33dd4                   0  ...     2     3.0
# D62170955-5fc5-434e-8e6a-6a9e139851c4                   0  ...     0     1.0
# Dbfa7903c-bd06-4e1c-9d22-a3d39ed96aee                   0  ...     0     1.0
#
#                                        N Stage M Stage Pathologic Stage  \
# PUF_CASE_ID
# D66f458f9-bdc0-4c95-94a3-a5f8c5bb74f9      0.0       0       No surgery
# Dfc68ea23-71aa-4b0d-87c0-587b4ce13d04      1.0       0       No surgery
# D54a1d0da-4328-4ca5-8481-87cd73b33dd4      0.0       0       No surgery
# D62170955-5fc5-434e-8e6a-6a9e139851c4      0.0       0       No surgery
# Dbfa7903c-bd06-4e1c-9d22-a3d39ed96aee      0.0       0       No surgery
#
#                                        Facility Volume Quartile  \
# PUF_CASE_ID
# D66f458f9-bdc0-4c95-94a3-a5f8c5bb74f9                       3.0
# Dfc68ea23-71aa-4b0d-87c0-587b4ce13d04                       1.0
# D54a1d0da-4328-4ca5-8481-87cd73b33dd4                       3.0
# D62170955-5fc5-434e-8e6a-6a9e139851c4                       3.0
# Dbfa7903c-bd06-4e1c-9d22-a3d39ed96aee                       4.0
#
#                                       3-yr Mortality      Keratinizing  \
# PUF_CASE_ID
# D66f458f9-bdc0-4c95-94a3-a5f8c5bb74f9            0.0  Not Keratinizing
# Dfc68ea23-71aa-4b0d-87c0-587b4ce13d04            0.0  Not Keratinizing
# D54a1d0da-4328-4ca5-8481-87cd73b33dd4            0.0  Not Keratinizing
# D62170955-5fc5-434e-8e6a-6a9e139851c4            0.0  Not Keratinizing
# Dbfa7903c-bd06-4e1c-9d22-a3d39ed96aee            0.0  Not Keratinizing
#
#                                            Basaloid      Cloacogenic
# PUF_CASE_ID
# D66f458f9-bdc0-4c95-94a3-a5f8c5bb74f9  Not Basaloid  Not Cloacogenic
# Dfc68ea23-71aa-4b0d-87c0-587b4ce13d04      Basaloid  Not Cloacogenic
# D54a1d0da-4328-4ca5-8481-87cd73b33dd4  Not Basaloid  Not Cloacogenic
# D62170955-5fc5-434e-8e6a-6a9e139851c4  Not Basaloid  Not Cloacogenic
# Dbfa7903c-bd06-4e1c-9d22-a3d39ed96aee  Not Basaloid  Not Cloacogenic
#
# [5 rows x 35 columns]

# %%
histo = ['Keratinizing', 'Basaloid', 'Cloacogenic']
for x in histo:
    data.loc[data[x].str.contains('Not'), x] = 0
    data.loc[data[x] !=0 , x] = 1

# %%
data.loc[data['Lymphovascular Invasion'] == 'No', 'Lymphovascular Invasion'] = 0
data.loc[data['Lymphovascular Invasion'] == 'Yes', 'Lymphovascular Invasion'] = 2
data.loc[data['Lymphovascular Invasion'] == 'nan', 'Lymphovascular Invasion'] = 1
data['Lymphovascular Invasion'].value_counts()
# Out:
# 1    27904
# 0     4818
# 2     1068
# Name: Lymphovascular Invasion, dtype: int64

# %%
no_encode = ['Stage', 'Facility Volume Quartile', 'APR', 'Keratinizing', 'Basaloid', 'Cloacogenic', 'Lymphovascular Invasion', 'Charlson-Deyo Score', 'Year of Diagnosis']
cat_cols.append('Reason for No Surgery')
cat_cols.append('Surgical Margins')
#remove no_encode from cat_cols
for x in no_encode:
    try:
        cat_cols.remove(x)
    except ValueError:
        pass
for x in cat_cols:
    le = LabelEncoder()
    le.fit(data[x])
    keys = le.classes_
    values = le.transform(le.classes_)
    label_dict = dict(zip(keys, values))
    print('col:', x)
    print(label_dict)
    data[x] = le.transform(data[x])
# Out:
# col: Facility Type
# {'Academic/Research Program': 0, 'Community Cancer Program': 1, 'Comprehensive Community Cancer Program': 2, 'Integrated Network Cancer Program': 3, 'nan': 4}
# col: Facility Location
# {'Midwest': 0, 'NE': 1, 'South': 2, 'West': 3, 'nan': 4}
# col: Sex
# {'Female': 0, 'Male': 1}
# col: Race
# {'Asian': 0, 'Black': 1, 'Other': 2, 'White': 3, 'nan': 4}
# col: Hispanic Ethnicity
# {'Hispanic': 0, 'Non-Hispanic': 1, 'nan': 2}
# col: Insurance Status
# {'Medicaid': 0, 'Medicare/Public': 1, 'Not Insured': 2, 'Private Insurance or Managed Care': 3, 'nan': 4}
# col: Urban/Rural
# {'Rural': 0, 'Suburban': 1, 'Urban': 2, 'nan': 3}
# col: Grade
# {'Cell type not determined, not stated or not applicable': 0, 'Grade I, Well differentiated': 1, 'Grade II, Moderately differentiated': 2, 'Grade III, Poorly differentiated': 3, 'Grade IV, Undifferentiated or anaplastic': 4}
# col: Post-op Readmission
# {'No surgery/readmission': 0, 'Readmission': 1, 'nan': 2}
# col: Chemotherapy
# {'Multi-agent': 0, 'None': 1, 'Single-agent': 2, 'nan': 3}
# col: No High School Degree, Quartile
# {'13.0-20.9%': 0, '7.0-12.9%': 1, '<7.0%': 2, '>=21.0%': 3, 'nan': 4}
# col: Income, Quartile
# {'$30,000 - $34,999': 0, '$35,000 - $45,999': 1, '< $30,000': 2, '>=$46,000': 3, 'nan': 4}
# col: Medicaid Expansion
# {'Early Expansion (before 1/2014)': 0, 'Late Expansion States (after 1/2014)': 1, 'Non-Expansion State': 2, 'Suppressed for Ages 0-39': 3}
# col: APR performed
# {'0.0': 0, '1.0': 1}
# col: T Stage
# {'0.0': 0, '1.0': 1, '2.0': 2, '3.0': 3, '4.0': 4, 'nan': 5}
# col: N Stage
# {'0.0': 0, '1.0': 1, 'nan': 2}
# col: M Stage
# {'0': 0}
# col: Pathologic Stage
# {'0': 0, '2': 1, '3': 2, 'No surgery': 3, 'nan': 4}
# col: 3-yr Mortality
# {'0.0': 0, '1.0': 1}
# col: Reason for No Surgery
# {'Contra-indicated': 0, 'Not indicated': 1, 'Refused': 2, 'Unknown reason': 3}
# col: Surgical Margins
# {'Negative': 0, 'No Surgery': 1, 'Positive': 2}

# %%
data.head()
# Out:
#                                        Facility Type  Facility Location   Age  \
# PUF_CASE_ID
# D66f458f9-bdc0-4c95-94a3-a5f8c5bb74f9              0                  0  52.0
# Dfc68ea23-71aa-4b0d-87c0-587b4ce13d04              0                  3  49.0
# D54a1d0da-4328-4ca5-8481-87cd73b33dd4              0                  0  58.0
# D62170955-5fc5-434e-8e6a-6a9e139851c4              0                  0  80.0
# Dbfa7903c-bd06-4e1c-9d22-a3d39ed96aee              3                  0  42.0
#
#                                        Sex  Race  Hispanic Ethnicity  \
# PUF_CASE_ID
# D66f458f9-bdc0-4c95-94a3-a5f8c5bb74f9    0     3                   1
# Dfc68ea23-71aa-4b0d-87c0-587b4ce13d04    0     3                   1
# D54a1d0da-4328-4ca5-8481-87cd73b33dd4    1     3                   1
# D62170955-5fc5-434e-8e6a-6a9e139851c4    0     3                   1
# Dbfa7903c-bd06-4e1c-9d22-a3d39ed96aee    0     3                   1
#
#                                        Insurance Status  Urban/Rural  \
# PUF_CASE_ID
# D66f458f9-bdc0-4c95-94a3-a5f8c5bb74f9                 2            2
# Dfc68ea23-71aa-4b0d-87c0-587b4ce13d04                 3            2
# D54a1d0da-4328-4ca5-8481-87cd73b33dd4                 0            2
# D62170955-5fc5-434e-8e6a-6a9e139851c4                 1            2
# Dbfa7903c-bd06-4e1c-9d22-a3d39ed96aee                 3            2
#
#                                        Distance from Hospital  \
# PUF_CASE_ID
# D66f458f9-bdc0-4c95-94a3-a5f8c5bb74f9                     3.6
# Dfc68ea23-71aa-4b0d-87c0-587b4ce13d04                    11.4
# D54a1d0da-4328-4ca5-8481-87cd73b33dd4                    14.0
# D62170955-5fc5-434e-8e6a-6a9e139851c4                     8.4
# Dbfa7903c-bd06-4e1c-9d22-a3d39ed96aee                    12.7
#
#                                       Charlson-Deyo Score  ... Stage  T Stage  \
# PUF_CASE_ID                                                ...
# D66f458f9-bdc0-4c95-94a3-a5f8c5bb74f9                   0  ...     1        2
# Dfc68ea23-71aa-4b0d-87c0-587b4ce13d04                   0  ...     3        2
# D54a1d0da-4328-4ca5-8481-87cd73b33dd4                   0  ...     2        3
# D62170955-5fc5-434e-8e6a-6a9e139851c4                   0  ...     0        1
# Dbfa7903c-bd06-4e1c-9d22-a3d39ed96aee                   0  ...     0        1
#
#                                        N Stage M Stage  Pathologic Stage  \
# PUF_CASE_ID
# D66f458f9-bdc0-4c95-94a3-a5f8c5bb74f9        0       0                 3
# Dfc68ea23-71aa-4b0d-87c0-587b4ce13d04        1       0                 3
# D54a1d0da-4328-4ca5-8481-87cd73b33dd4        0       0                 3
# D62170955-5fc5-434e-8e6a-6a9e139851c4        0       0                 3
# Dbfa7903c-bd06-4e1c-9d22-a3d39ed96aee        0       0                 3
#
#                                        Facility Volume Quartile  \
# PUF_CASE_ID
# D66f458f9-bdc0-4c95-94a3-a5f8c5bb74f9                       3.0
# Dfc68ea23-71aa-4b0d-87c0-587b4ce13d04                       1.0
# D54a1d0da-4328-4ca5-8481-87cd73b33dd4                       3.0
# D62170955-5fc5-434e-8e6a-6a9e139851c4                       3.0
# Dbfa7903c-bd06-4e1c-9d22-a3d39ed96aee                       4.0
#
#                                        3-yr Mortality  Keratinizing  Basaloid  \
# PUF_CASE_ID
# D66f458f9-bdc0-4c95-94a3-a5f8c5bb74f9               0             0         0
# Dfc68ea23-71aa-4b0d-87c0-587b4ce13d04               0             0         1
# D54a1d0da-4328-4ca5-8481-87cd73b33dd4               0             0         0
# D62170955-5fc5-434e-8e6a-6a9e139851c4               0             0         0
# Dbfa7903c-bd06-4e1c-9d22-a3d39ed96aee               0             0         0
#
#                                        Cloacogenic
# PUF_CASE_ID
# D66f458f9-bdc0-4c95-94a3-a5f8c5bb74f9            0
# Dfc68ea23-71aa-4b0d-87c0-587b4ce13d04            0
# D54a1d0da-4328-4ca5-8481-87cd73b33dd4            0
# D62170955-5fc5-434e-8e6a-6a9e139851c4            0
# Dbfa7903c-bd06-4e1c-9d22-a3d39ed96aee            0
#
# [5 rows x 35 columns]

# %%
#apply the standard scaler to the numerical columns
scaler = StandardScaler()
for x in num_cols:
    data[x] = scaler.fit_transform(data[x].values.reshape(-1,1))

# %%
data['Year of Diagnosis'].value_counts()
# Out:
# 2016    3177
# 2014    3054
# 2015    2975
# 2013    2899
# 2012    2634
# 2011    2458
# 2017    2405
# 2009    2307
# 2010    2276
# 2008    2145
# 2007    1870
# 2006    1672
# 2005    1566
# 2004    1562
# 2018     790
# Name: Year of Diagnosis, dtype: int64

# %%
pd.crosstab(data['Year of Diagnosis'], data['3-yr Mortality'], normalize='index')
# Out:
# 3-yr Mortality            0         1
# Year of Diagnosis
# 2004               0.731754  0.268246
# 2005               0.737548  0.262452
# 2006               0.765550  0.234450
# 2007               0.766310  0.233690
# 2008               0.769231  0.230769
# 2009               0.767664  0.232336
# 2010               0.777680  0.222320
# 2011               0.785598  0.214402
# 2012               0.786257  0.213743
# 2013               0.773025  0.226975
# 2014               0.798625  0.201375
# 2015               0.796975  0.203025
# 2016               0.796034  0.203966
# 2017               0.739709  0.260291
# 2018               0.302532  0.697468

# %%
print(data.shape[0] * 0.8)
print(data.shape[0] * 0.2)
# Out:
# 27032.0
# 6758.0

# %%
data['3-yr Mortality'].value_counts(normalize=True)
# Out:
# 0    0.763599
# 1    0.236401
# Name: 3-yr Mortality, dtype: float64

# %%
data.to_csv('data/data_os_clean_imputed.csv')

# %%
data['Year of Diagnosis'] = data['Year of Diagnosis'].astype(int)

# %%
test = data[data['Year of Diagnosis'] > 2014]
print(test.shape)
train = data[data['Year of Diagnosis'] <= 2014]
print(train.shape)
# Out:
# (9347, 35)
# (24443, 35)

# %%
# train_10 = train[train['Year of Diagnosis'] > 2010]

# %%
# test_17 = test[test['Year of Diagnosis'] < 2017]

# %%
# test.drop('Year of Diagnosis', axis=1, inplace=True)
# test_17.drop('Year of Diagnosis', axis=1, inplace=True)
# train.drop('Year of Diagnosis', axis=1, inplace=True)
# train_10.drop('Year of Diagnosis', axis=1, inplace=True)

# %%
print(test.shape[0] / data.shape[0])
# Out:
# 0.27662030186445696

# %%
test.to_csv('data/test_os.csv', index=False)
# test_17.to_csv('data/test_17_os.csv', index=False)
train.to_csv('data/train_os.csv', index=False)
# train_10.to_csv('data/train_10_os.csv', index=False)

# %%
test['Year of Diagnosis'].value_counts()
# Out:
# 2016    3177
# 2015    2975
# 2017    2405
# 2018     790
# Name: Year of Diagnosis, dtype: int64

# %%
train['3-yr Mortality'].value_counts(normalize=True)
# Out:
# 0    0.772573
# 1    0.227427
# Name: 3-yr Mortality, dtype: float64

# %%
test['3-yr Mortality'].value_counts(normalize=True)
# Out:
# 0    0.740131
# 1    0.259869
# Name: 3-yr Mortality, dtype: float64

# %%
train['Year of Diagnosis'].value_counts()
# Out:
# 2014    3054
# 2013    2899
# 2012    2634
# 2011    2458
# 2009    2307
# 2010    2276
# 2008    2145
# 2007    1870
# 2006    1672
# 2005    1566
# 2004    1562
# Name: Year of Diagnosis, dtype: int64

# %%
data.iloc[:, 0:15].head()
# Out:
#                                        Facility Type  Facility Location  \
# PUF_CASE_ID
# D66f458f9-bdc0-4c95-94a3-a5f8c5bb74f9              0                  0
# Dfc68ea23-71aa-4b0d-87c0-587b4ce13d04              0                  3
# D54a1d0da-4328-4ca5-8481-87cd73b33dd4              0                  0
# D62170955-5fc5-434e-8e6a-6a9e139851c4              0                  0
# Dbfa7903c-bd06-4e1c-9d22-a3d39ed96aee              3                  0
#
#                                             Age  Sex  Race  \
# PUF_CASE_ID
# D66f458f9-bdc0-4c95-94a3-a5f8c5bb74f9 -0.707231    0     3
# Dfc68ea23-71aa-4b0d-87c0-587b4ce13d04 -0.955281    0     3
# D54a1d0da-4328-4ca5-8481-87cd73b33dd4 -0.211132    1     3
# D62170955-5fc5-434e-8e6a-6a9e139851c4  1.607898    0     3
# Dbfa7903c-bd06-4e1c-9d22-a3d39ed96aee -1.534063    0     3
#
#                                        Hispanic Ethnicity  Insurance Status  \
# PUF_CASE_ID
# D66f458f9-bdc0-4c95-94a3-a5f8c5bb74f9                   1                 2
# Dfc68ea23-71aa-4b0d-87c0-587b4ce13d04                   1                 3
# D54a1d0da-4328-4ca5-8481-87cd73b33dd4                   1                 0
# D62170955-5fc5-434e-8e6a-6a9e139851c4                   1                 1
# Dbfa7903c-bd06-4e1c-9d22-a3d39ed96aee                   1                 3
#
#                                        Urban/Rural  Distance from Hospital  \
# PUF_CASE_ID
# D66f458f9-bdc0-4c95-94a3-a5f8c5bb74f9            2               -0.678043
# Dfc68ea23-71aa-4b0d-87c0-587b4ce13d04            2               -0.173059
# D54a1d0da-4328-4ca5-8481-87cd73b33dd4            2               -0.004731
# D62170955-5fc5-434e-8e6a-6a9e139851c4            2               -0.367283
# Dbfa7903c-bd06-4e1c-9d22-a3d39ed96aee            2               -0.088895
#
#                                       Charlson-Deyo Score  Year of Diagnosis  \
# PUF_CASE_ID
# D66f458f9-bdc0-4c95-94a3-a5f8c5bb74f9                   0               2016
# Dfc68ea23-71aa-4b0d-87c0-587b4ce13d04                   0               2004
# D54a1d0da-4328-4ca5-8481-87cd73b33dd4                   0               2014
# D62170955-5fc5-434e-8e6a-6a9e139851c4                   0               2017
# Dbfa7903c-bd06-4e1c-9d22-a3d39ed96aee                   0               2014
#
#                                        Grade  Tumor Size  \
# PUF_CASE_ID
# D66f458f9-bdc0-4c95-94a3-a5f8c5bb74f9      2   -0.038291
# Dfc68ea23-71aa-4b0d-87c0-587b4ce13d04      2    0.246424
# D54a1d0da-4328-4ca5-8481-87cd73b33dd4      2    2.239425
# D62170955-5fc5-434e-8e6a-6a9e139851c4      3   -0.655172
# Dbfa7903c-bd06-4e1c-9d22-a3d39ed96aee      3   -0.892434
#
#                                       Lymphovascular Invasion  \
# PUF_CASE_ID
# D66f458f9-bdc0-4c95-94a3-a5f8c5bb74f9                       0
# Dfc68ea23-71aa-4b0d-87c0-587b4ce13d04                       1
# D54a1d0da-4328-4ca5-8481-87cd73b33dd4                       0
# D62170955-5fc5-434e-8e6a-6a9e139851c4                       1
# Dbfa7903c-bd06-4e1c-9d22-a3d39ed96aee                       0
#
#                                        Surgical Margins
# PUF_CASE_ID
# D66f458f9-bdc0-4c95-94a3-a5f8c5bb74f9                 1
# Dfc68ea23-71aa-4b0d-87c0-587b4ce13d04                 1
# D54a1d0da-4328-4ca5-8481-87cd73b33dd4                 1
# D62170955-5fc5-434e-8e6a-6a9e139851c4                 0
# Dbfa7903c-bd06-4e1c-9d22-a3d39ed96aee                 2

# %%
data.iloc[:, 15:30].head()
# Out:
#                                        Post-op Length of Stay  \
# PUF_CASE_ID
# D66f458f9-bdc0-4c95-94a3-a5f8c5bb74f9               -0.101252
# Dfc68ea23-71aa-4b0d-87c0-587b4ce13d04               -0.101252
# D54a1d0da-4328-4ca5-8481-87cd73b33dd4               -0.101252
# D62170955-5fc5-434e-8e6a-6a9e139851c4               -0.101252
# Dbfa7903c-bd06-4e1c-9d22-a3d39ed96aee               -0.101252
#
#                                        Post-op Readmission  \
# PUF_CASE_ID
# D66f458f9-bdc0-4c95-94a3-a5f8c5bb74f9                    0
# Dfc68ea23-71aa-4b0d-87c0-587b4ce13d04                    0
# D54a1d0da-4328-4ca5-8481-87cd73b33dd4                    0
# D62170955-5fc5-434e-8e6a-6a9e139851c4                    0
# Dbfa7903c-bd06-4e1c-9d22-a3d39ed96aee                    0
#
#                                        Reason for No Surgery  \
# PUF_CASE_ID
# D66f458f9-bdc0-4c95-94a3-a5f8c5bb74f9                      1
# Dfc68ea23-71aa-4b0d-87c0-587b4ce13d04                      1
# D54a1d0da-4328-4ca5-8481-87cd73b33dd4                      1
# D62170955-5fc5-434e-8e6a-6a9e139851c4                      1
# Dbfa7903c-bd06-4e1c-9d22-a3d39ed96aee                      1
#
#                                        Treatment Started, Days from Dx  \
# PUF_CASE_ID
# D66f458f9-bdc0-4c95-94a3-a5f8c5bb74f9                         1.659776
# Dfc68ea23-71aa-4b0d-87c0-587b4ce13d04                        -0.967383
# D54a1d0da-4328-4ca5-8481-87cd73b33dd4                        -0.370301
# D62170955-5fc5-434e-8e6a-6a9e139851c4                        -0.410107
# Dbfa7903c-bd06-4e1c-9d22-a3d39ed96aee                         0.027753
#
#                                        Chemotherapy  \
# PUF_CASE_ID
# D66f458f9-bdc0-4c95-94a3-a5f8c5bb74f9             0
# Dfc68ea23-71aa-4b0d-87c0-587b4ce13d04             0
# D54a1d0da-4328-4ca5-8481-87cd73b33dd4             0
# D62170955-5fc5-434e-8e6a-6a9e139851c4             0
# Dbfa7903c-bd06-4e1c-9d22-a3d39ed96aee             0
#
#                                        No High School Degree, Quartile  \
# PUF_CASE_ID
# D66f458f9-bdc0-4c95-94a3-a5f8c5bb74f9                                3
# Dfc68ea23-71aa-4b0d-87c0-587b4ce13d04                                1
# D54a1d0da-4328-4ca5-8481-87cd73b33dd4                                2
# D62170955-5fc5-434e-8e6a-6a9e139851c4                                4
# Dbfa7903c-bd06-4e1c-9d22-a3d39ed96aee                                2
#
#                                        Income, Quartile  Medicaid Expansion  \
# PUF_CASE_ID
# D66f458f9-bdc0-4c95-94a3-a5f8c5bb74f9                 2                   2
# Dfc68ea23-71aa-4b0d-87c0-587b4ce13d04                 1                   0
# D54a1d0da-4328-4ca5-8481-87cd73b33dd4                 3                   0
# D62170955-5fc5-434e-8e6a-6a9e139851c4                 4                   0
# Dbfa7903c-bd06-4e1c-9d22-a3d39ed96aee                 3                   0
#
#                                        Total Dose  APR performed Stage  \
# PUF_CASE_ID
# D66f458f9-bdc0-4c95-94a3-a5f8c5bb74f9   -2.347018              0     1
# Dfc68ea23-71aa-4b0d-87c0-587b4ce13d04    0.340400              0     3
# D54a1d0da-4328-4ca5-8481-87cd73b33dd4    0.845635              0     2
# D62170955-5fc5-434e-8e6a-6a9e139851c4    0.458646              0     0
# Dbfa7903c-bd06-4e1c-9d22-a3d39ed96aee    0.340400              0     0
#
#                                        T Stage  N Stage  M Stage  \
# PUF_CASE_ID
# D66f458f9-bdc0-4c95-94a3-a5f8c5bb74f9        2        0        0
# Dfc68ea23-71aa-4b0d-87c0-587b4ce13d04        2        1        0
# D54a1d0da-4328-4ca5-8481-87cd73b33dd4        3        0        0
# D62170955-5fc5-434e-8e6a-6a9e139851c4        1        0        0
# Dbfa7903c-bd06-4e1c-9d22-a3d39ed96aee        1        0        0
#
#                                        Pathologic Stage
# PUF_CASE_ID
# D66f458f9-bdc0-4c95-94a3-a5f8c5bb74f9                 3
# Dfc68ea23-71aa-4b0d-87c0-587b4ce13d04                 3
# D54a1d0da-4328-4ca5-8481-87cd73b33dd4                 3
# D62170955-5fc5-434e-8e6a-6a9e139851c4                 3
# Dbfa7903c-bd06-4e1c-9d22-a3d39ed96aee                 3

# %%
data.iloc[:, 30:45].head()
# Out:
#                                       Facility Volume Quartile  \
# PUF_CASE_ID
# D66f458f9-bdc0-4c95-94a3-a5f8c5bb74f9                      3.0
# Dfc68ea23-71aa-4b0d-87c0-587b4ce13d04                      1.0
# D54a1d0da-4328-4ca5-8481-87cd73b33dd4                      3.0
# D62170955-5fc5-434e-8e6a-6a9e139851c4                      3.0
# Dbfa7903c-bd06-4e1c-9d22-a3d39ed96aee                      4.0
#
#                                        3-yr Mortality Keratinizing Basaloid  \
# PUF_CASE_ID
# D66f458f9-bdc0-4c95-94a3-a5f8c5bb74f9               0            0        0
# Dfc68ea23-71aa-4b0d-87c0-587b4ce13d04               0            0        1
# D54a1d0da-4328-4ca5-8481-87cd73b33dd4               0            0        0
# D62170955-5fc5-434e-8e6a-6a9e139851c4               0            0        0
# Dbfa7903c-bd06-4e1c-9d22-a3d39ed96aee               0            0        0
#
#                                       Cloacogenic
# PUF_CASE_ID
# D66f458f9-bdc0-4c95-94a3-a5f8c5bb74f9           0
# Dfc68ea23-71aa-4b0d-87c0-587b4ce13d04           0
# D54a1d0da-4328-4ca5-8481-87cd73b33dd4           0
# D62170955-5fc5-434e-8e6a-6a9e139851c4           0
# Dbfa7903c-bd06-4e1c-9d22-a3d39ed96aee           0

# %%
data['3-yr Mortality'].value_counts(normalize=True)
# Out:
# 0    0.763599
# 1    0.236401
# Name: 3-yr Mortality, dtype: float64

# %%
data['3-yr Mortality'].value_counts()
# Out:
# 0    25802
# 1     7988
# Name: 3-yr Mortality, dtype: int64
